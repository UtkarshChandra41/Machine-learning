# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/utkarshchandra/Documents/Machine Leraning /Basics/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'], c=df['placement'])

# %%
#Extracting INPUTS & OUTPUTS
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
#Train test split
from sklearn.model_selection import train_test_split
train_test_split(x,y,test_size=0.1)    #x - independet and y is dependent variable
# Out:
# [    cgpa     iq
#  59   4.8  112.0
#  65   8.1  166.0
#  78   6.1   81.0
#  93   6.8  112.0
#  48   6.6  138.0
#  ..   ...    ...
#  74   6.7  154.0
#  4    5.8  142.0
#  97   6.7  182.0
#  41   5.4  114.0
#  70   6.3  127.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  49   5.4  135.0
#  12   5.4  139.0
#  13   6.4  116.0
#  32   7.0  139.0
#  50   3.5  233.0
#  20   6.6  120.0
#  85   5.8  166.0
#  21   7.1  151.0
#  42   7.6   89.0
#  19   5.2  132.0,
#  59    0
#  65    1
#  78    0
#  93    1
#  48    1
#       ..
#  74    1
#  4     0
#  97    1
#  41    0
#  70    1
#  Name: placement, Length: 90, dtype: int64,
#  49    0
#  12    0
#  13    1
#  32    1
#  50    0
#  20    1
#  85    1
#  21    1
#  42    1
#  19    0
#  Name: placement, dtype: int64]

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 97   6.7  182.0
# 99   6.2  113.0
# 62   6.0  102.0
# 73   4.9   61.0
# 3    7.4  132.0
# ..   ...    ...
# 10   6.0   45.0
# 96   4.4   42.0
# 5    7.1   48.0
# 41   5.4  114.0
# 23   4.7   87.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 97    1
# 99    1
# 62    0
# 73    0
# 3     1
#      ..
# 10    1
# 96    0
# 5     1
# 41    0
# 23    0
# Name: placement, Length: 90, dtype: int64

# %%
#SCALING
from sklearn.preprocessing import StandardScaler

# %%
#then we will make an object of it
scalar=StandardScaler()

# %%
X_train=scalar.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.61572706,  1.41989645],
#        [ 0.18813882, -0.29959594],
#        [ 0.01710353, -0.57371791],
#        [-0.92359058, -1.59544527],
#        [ 1.21435058,  0.17388747],
#        [-1.09462588, -0.1002345 ],
#        [-1.77876705, -0.39927665],
#        [ 0.44469176,  0.8716525 ],
#        [-0.75255529, -1.47084437],
#        [-2.12083764,  2.6908256 ],
#        [ 0.01710353, -1.47084437],
#        [ 0.10262118, -1.49576455],
#        [-0.49600235, -0.44911701],
#        [ 0.7012447 , -0.32451611],
#        [ 0.44469176, -2.19352957],
#        [-0.75255529,  0.07420676],
#        [-0.92359058, -0.12515468],
#        [-0.83807294, -1.54560491],
#        [ 0.7012447 , -0.05039414],
#        [ 1.38538588,  0.07420676],
#        [ 0.61572706,  0.72213142],
#        [ 0.27365647, -0.54879773],
#        [ 1.9840094 ,  1.07101393],
#        [-1.6932494 , -0.62355827],
#        [ 0.10262118, -1.09704168],
#        [-0.23944941,  0.37324891],
#        [ 0.27365647,  0.07420676],
# ...

# %%
X_test=scalar.transform(X_test)

# %%
#TRAIN THE MODEL
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
#MODEL TRAINING
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#EVALUATE THE MODEL
y_pred=clf.predict(X_test)

# %%
y_test
# Out:
# 54    1
# 57    1
# 28    0
# 8     0
# 77    1
# 64    1
# 49    0
# 19    0
# 35    1
# 67    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
#visualization
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train,y_train.values, clf=clf ,legend=2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
